# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.linear_model import LinearRegression

data = pd.read_csv("../train.csv")

data.head()
# Out:
#       tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0  189123628             10.5     834.0           56.0              0.0000
# 1  189125358             10.5     791.0           47.0              0.0000
# 2  189125719             10.5    1087.0           80.0              0.0000
# 3  189127273             10.5     598.0          271.0             15.6638
# 4  189128020              NaN       NaN            NaN                 NaN
#
#    meter_waiting_till_pickup     pickup_time       drop_time  pick_lat  \
# 0                       64.0  11/1/2019 0:20  11/1/2019 0:34   6.86252
# 1                      134.0  11/1/2019 0:56  11/1/2019 1:09   6.88589
# 2                       61.0  11/1/2019 1:08  11/1/2019 1:26   6.90839
# 3                       68.0  11/1/2019 2:27  11/1/2019 2:37   6.92570
# 4                        NaN  11/1/2019 3:34  11/1/2019 3:51   6.87441
#
#    pick_lon  drop_lat  drop_lon    fare    label
# 0   79.8993   6.90330   79.8783  270.32  correct
# 1   79.8984   6.91373   79.8923  197.85  correct
# 2   79.8651   6.93669   79.9146  301.64  correct
# 3   79.8895   6.92748   79.8971   82.30  correct
# 4   79.8615   6.84478   79.9290  358.39  correct

# %%
data["label"].value_counts()
# Out:
# correct      15495
# incorrect     1681
# Name: label, dtype: int64

# %%
test = pd.read_csv("../test.csv")

test.head()
# Out:
#       tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0  213284604             10.5       924             42              2.4486
# 1  213286352             10.5      4249             20              0.0000
# 2  213293973             10.5      1552            255              2.6588
# 3  213294622             10.5       462             16              0.0000
# 4  213298687             10.5       814            392             12.3692
#
#    meter_waiting_till_pickup    pickup_time      drop_time  pick_lat  \
# 0                        148  2/1/2020 0:38  2/1/2020 0:53   6.83454
# 1                         91  2/1/2020 1:02  2/1/2020 2:13   6.91168
# 2                         23  2/1/2020 5:02  2/1/2020 5:28   6.92145
# 3                        198  2/1/2020 5:30  2/1/2020 5:38   6.77433
# 4                         69  2/1/2020 7:00  2/1/2020 7:14   6.97968
#
#    pick_lon  drop_lat  drop_lon     fare
# 0   79.8750   6.77490   79.8840   289.27
# 1   79.8723   6.55091   79.9706  1912.70
# 2   79.8478   6.90539   79.8989   394.00
# 3   79.9416   6.80401   79.9407   154.32
# 4   79.9130   6.98875   79.8914   147.47

# %% [markdown]
# # EDA

# %%
test.isna().describe()
# Out:
#        tripid additional_fare duration meter_waiting meter_waiting_fare  \
# count    8576            8576     8576          8576               8576
# unique      1               1        1             1                  1
# top     False           False    False         False              False
# freq     8576            8576     8576          8576               8576
#
#        meter_waiting_till_pickup pickup_time drop_time pick_lat pick_lon  \
# count                       8576        8576      8576     8576     8576
# unique                         1           1         1        1        1
# top                        False       False     False    False    False
# freq                        8576        8576      8576     8576     8576
#
#        drop_lat drop_lon   fare
# count      8576     8576   8576
# unique        1        1      1
# top       False    False  False
# freq       8576     8576   8576

# %%
data[data["label"]=="incorrect"].isna().describe()
# Out:
#        tripid additional_fare duration meter_waiting meter_waiting_fare  \
# count    1681            1681     1681          1681               1681
# unique      1               2        2             2                  2
# top     False           False    False         False              False
# freq     1681            1532     1532          1532               1532
#
#        meter_waiting_till_pickup pickup_time drop_time pick_lat pick_lon  \
# count                       1681        1681      1681     1681     1681
# unique                         2           1         1        1        1
# top                        False       False     False    False    False
# freq                        1532        1681      1681     1681     1681
#
#        drop_lat drop_lon   fare  label
# count      1681     1681   1681   1681
# unique        1        1      2      1
# top       False    False  False  False
# freq       1681     1681   1544   1681

# %%
data[data["label"]=="incorrect"].dropna().shape
# Out:
# (1526, 14)

# %% [markdown]
# # Feature Engineering

# %%
data["pickup_time"] = pd.to_datetime(data["pickup_time"])
data["drop_time"] = pd.to_datetime(data["drop_time"])
data["label"] = data["label"].apply(lambda x: 1 if x=="correct" else 0)

test["pickup_time"] = pd.to_datetime(test["pickup_time"])
test["drop_time"] = pd.to_datetime(test["drop_time"])
#test["label"] = test["label"].apply(lambda x: 1 if x=="correct" else 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-eb0c268df89a> in <module>
#       5 test["pickup_time"] = pd.to_datetime(test["pickup_time"])
#       6 test["drop_time"] = pd.to_datetime(test["drop_time"])
# ----> 7 test["label"] = test["label"].apply(lambda x: 1 if x=="correct" else 0)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'

# %%
data["pickup_time_minuts"] = data["pickup_time"].apply(lambda x: int(x.strftime("%M"))+int(x.strftime("%H"))*60)
data["drop_time_minuts"] = data["drop_time"].apply(lambda x: int(x.strftime("%M"))+int(x.strftime("%H"))*60)
#data["pickup_time_minuts"]#.dt.strftime("%h%m%s").astype(int)

test["pickup_time_minuts"] = test["pickup_time"].apply(lambda x: int(x.strftime("%M"))+int(x.strftime("%H"))*60)
test["drop_time_minuts"] = test["drop_time"].apply(lambda x: int(x.strftime("%M"))+int(x.strftime("%H"))*60)
#data["pickup_time_minuts"]#.dt.strftime("%h%m%s").astype(int)

# %%
data["date_diff"] = data['drop_time'] - data['pickup_time']
data['date_diff']=data['date_diff']/np.timedelta64(1,'s')

test["date_diff"] = test['drop_time'] - test['pickup_time']
test['date_diff']=test['date_diff']/np.timedelta64(1,'s')

# %%
data.corr()
# Out:
#                              tripid  additional_fare  duration  meter_waiting  \
# tripid                     1.000000         0.019145 -0.019747      -0.016882
# additional_fare            0.019145         1.000000 -0.000772       0.197605
# duration                  -0.019747        -0.000772  1.000000       0.969787
# meter_waiting             -0.016882         0.197605  0.969787       1.000000
# meter_waiting_fare        -0.017301         0.199604  0.968666       0.999474
# meter_waiting_till_pickup -0.017864         0.002355  0.040578       0.030447
# pick_lat                   0.027357         0.009124 -0.027079      -0.016171
# pick_lon                   0.027085         0.000621 -0.025593      -0.014211
# drop_lat                   0.005512         0.004644 -0.015969      -0.010117
# drop_lon                   0.028426         0.001539 -0.013605      -0.007905
# fare                      -0.014595         0.315285  0.865256       0.870126
# label                      0.062490        -0.040910 -0.112955      -0.107266
# pickup_time_minuts         0.022025        -0.005085 -0.005873      -0.008998
# drop_time_minuts           0.023489        -0.004697 -0.005542      -0.015353
# date_diff                 -0.019198        -0.000812  0.999988       0.969771
#
#                            meter_waiting_fare  meter_waiting_till_pickup  \
# tripid                              -0.017301                  -0.017864
# additional_fare                      0.199604                   0.002355
# duration                             0.968666                   0.040578
# meter_waiting                        0.999474                   0.030447
# meter_waiting_fare                   1.000000                   0.029908
# meter_waiting_till_pickup            0.029908                   1.000000
# pick_lat                            -0.015014                   0.011393
# pick_lon                            -0.012483                   0.016509
# drop_lat                            -0.009430                   0.006949
# drop_lon                            -0.006805                   0.011065
# fare                                 0.865073                   0.045468
# label                               -0.103319                  -0.035320
# pickup_time_minuts                  -0.008362                  -0.006525
# drop_time_minuts                    -0.014828                  -0.009587
# date_diff                            0.968650                   0.040657
#
#                            pick_lat  pick_lon  drop_lat  drop_lon      fare  \
# tripid                     0.027357  0.027085  0.005512  0.028426 -0.014595
# additional_fare            0.009124  0.000621  0.004644  0.001539  0.315285
# duration                  -0.027079 -0.025593 -0.015969 -0.013605  0.865256
# meter_waiting             -0.016171 -0.014211 -0.010117 -0.007905  0.870126
# meter_waiting_fare        -0.015014 -0.012483 -0.009430 -0.006805  0.865073
# meter_waiting_till_pickup  0.011393  0.016509  0.006949  0.011065  0.045468
# pick_lat                   1.000000  0.522473  0.560466  0.340161 -0.024556
# pick_lon                   0.522473  1.000000  0.307313  0.654917 -0.035237
# drop_lat                   0.560466  0.307313  1.000000 -0.414566 -0.015530
# drop_lon                   0.340161  0.654917 -0.414566  1.000000 -0.014912
# fare                      -0.024556 -0.035237 -0.015530 -0.014912  1.000000
# label                     -0.029237 -0.037713 -0.012781 -0.030347 -0.183336
# pickup_time_minuts         0.016329  0.033701  0.003055  0.040187 -0.008705
# drop_time_minuts           0.015696  0.031080  0.002272  0.036987  0.000738
# date_diff                 -0.026462 -0.024942 -0.015487 -0.013263  0.865056
#
#                               label  pickup_time_minuts  drop_time_minuts  \
# tripid                     0.062490            0.022025          0.023489
# additional_fare           -0.040910           -0.005085         -0.004697
# duration                  -0.112955           -0.005873         -0.005542
# meter_waiting             -0.107266           -0.008998         -0.015353
# meter_waiting_fare        -0.103319           -0.008362         -0.014828
# meter_waiting_till_pickup -0.035320           -0.006525         -0.009587
# pick_lat                  -0.029237            0.016329          0.015696
# pick_lon                  -0.037713            0.033701          0.031080
# drop_lat                  -0.012781            0.003055          0.002272
# drop_lon                  -0.030347            0.040187          0.036987
# fare                      -0.183336           -0.008705          0.000738
# label                      1.000000           -0.005079         -0.003535
# pickup_time_minuts        -0.005079            1.000000          0.941394
# drop_time_minuts          -0.003535            0.941394          1.000000
# date_diff                 -0.111937           -0.004681         -0.006740
#
#                            date_diff
# tripid                     -0.019198
# additional_fare            -0.000812
# duration                    0.999988
# meter_waiting               0.969771
# meter_waiting_fare          0.968650
# meter_waiting_till_pickup   0.040657
# pick_lat                   -0.026462
# pick_lon                   -0.024942
# drop_lat                   -0.015487
# drop_lon                   -0.013263
# fare                        0.865056
# label                      -0.111937
# pickup_time_minuts         -0.004681
# drop_time_minuts           -0.006740
# date_diff                   1.000000

# %% [markdown]
# # Null Value handling

# %%
#data = data.dropna()
new_data = data[["date_diff" , "fare"]]

n_train = new_data[new_data["fare"].notna()]

fil_mod = LinearRegression()

fil_mod.fit(n_train[["date_diff"]] , n_train["fare"])

p = np.array(new_data[new_data["fare"].isna()]["date_diff"]).reshape(-1,1)

predicted = fil_mod.predict(p)

data.loc[data["fare"].isna(),"fare"] =  predicted

# %%
new_data = data[["date_diff" , "duration"]]

n_train = new_data[new_data["duration"].notna()]

fil_mod = LinearRegression()

fil_mod.fit(n_train[["date_diff"]] , n_train["duration"])

p = np.array(new_data[new_data["duration"].isna()]["date_diff"]).reshape(-1,1)

predicted = fil_mod.predict(p)

data.loc[data["duration"].isna(),"duration"] =  predicted

# %%
new_data = data[["date_diff" , "meter_waiting"]]

n_train = new_data[new_data["meter_waiting"].notna()]

fil_mod = LinearRegression()

fil_mod.fit(n_train[["date_diff"]] , n_train["meter_waiting"])

p = np.array(new_data[new_data["meter_waiting"].isna()]["date_diff"]).reshape(-1,1)

predicted = fil_mod.predict(p)

data.loc[data["meter_waiting"].isna(),"meter_waiting"] =  predicted

# %%
new_data = data[["date_diff" , "meter_waiting_fare"]]

n_train = new_data[new_data["meter_waiting_fare"].notna()]

fil_mod = LinearRegression()

fil_mod.fit(n_train[["date_diff"]] , n_train["meter_waiting_fare"])

p = np.array(new_data[new_data["meter_waiting_fare"].isna()]["date_diff"]).reshape(-1,1)

predicted = fil_mod.predict(p)

data.loc[data["meter_waiting_fare"].isna(),"meter_waiting_fare"] =  predicted

# %%
new_data = data[["date_diff" , "meter_waiting_till_pickup"]]

n_train = new_data[new_data["meter_waiting_till_pickup"].notna()]

fil_mod = LinearRegression()

fil_mod.fit(n_train[["date_diff"]] , n_train["meter_waiting_till_pickup"])

p = np.array(new_data[new_data["meter_waiting_till_pickup"].isna()]["date_diff"]).reshape(-1,1)

predicted = fil_mod.predict(p)

data.loc[data["meter_waiting_till_pickup"].isna(),"meter_waiting_till_pickup"] =  predicted

# %%
data.shape
# Out:
# (17176, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17176 entries, 0 to 17175
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tripid                     17176 non-null  int64
#  1   additional_fare            16974 non-null  float64
#  2   duration                   17176 non-null  float64
#  3   meter_waiting              17176 non-null  float64
#  4   meter_waiting_fare         17176 non-null  float64
#  5   meter_waiting_till_pickup  17176 non-null  float64
#  6   pickup_time                17176 non-null  datetime64[ns]
#  7   drop_time                  17176 non-null  datetime64[ns]
#  8   pick_lat                   17176 non-null  float64
#  9   pick_lon                   17176 non-null  float64
#  10  drop_lat                   17176 non-null  float64
#  11  drop_lon                   17176 non-null  float64
#  12  fare                       17176 non-null  float64
#  13  label                      17176 non-null  int64
#  14  pickup_time_minuts         17176 non-null  int64
#  15  drop_time_minuts           17176 non-null  int64
#  16  date_diff                  17176 non-null  float64
# dtypes: datetime64[ns](2), float64(11), int64(4)
# memory usage: 2.2 MB

# %%
data.drop(["tripid" , "pickup_time" , "drop_time", "additional_fare"], axis=1, inplace=True)

test.drop(["tripid" , "pickup_time" , "drop_time", "additional_fare"], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(data["date_diff"] , data["fare"])
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/sulhi/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.preprocessing import StandardScaler
X = data.drop(["label"],axis=1)
scale = StandardScaler()

X = scale.fit_transform(X)

Y = data["label"]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

print (y_train.value_counts())
print(y_test.value_counts())
# Out:
# 1    12371
# 0     1369
# Name: label, dtype: int64
# 1    3124
# 0     312
# Name: label, dtype: int64

# %% [markdown]
# # Fitting model

# %%
import xgboost

clf = xgboost.XGBClassifier(n_estimators = 1000)

clf.fit(X_train,y_train)

pred = clf.predict(X_test)

from sklearn.metrics import f1_score,confusion_matrix

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred))
# Out:
# [[ 157  155]
#  [  45 3079]]
# 0.9685435671594842
# /home/sulhi/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
pred_1 = clf.predict(X_train)

print (confusion_matrix(y_train,pred_1))

print (f1_score(y_train,pred_1))
# Out:
# [[ 1039   330]
#  [   22 12349]]
# 0.9859481037924152
# /home/sulhi/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=1000)

rf_clf.fit(X_train,y_train)

pred = rf_clf.predict(X_test)


print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred))
# Out:
# [[ 155  157]
#  [  29 3095]]
# 0.9708281053952322

# %%
pred_1 = rf_clf.predict(X_train)

print (confusion_matrix(y_train,pred_1))

print (f1_score(y_train,pred_1))
# Out:
# [[ 1369     0]
#  [    0 12371]]
# 1.0

# %%
t_pred = rf_clf.predict(scale.transform(test))

# %%
test_sub = pd.read_csv("../sample_submission.csv")

test_sub["prediction"] = t_pred

test_sub.to_csv("../rf_lrfn_1.csv" , index=False)

# %%
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression()

lr_clf.fit(X_train,y_train)

pred = lr_clf.predict(X_test)

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred))
# Out:
# [[  24  288]
#  [  12 3112]]
# 0.9540159411404047

# %%
pred_1 = lr_clf.predict(X_train)

print (confusion_matrix(y_train,pred_1))

print (f1_score(y_train,pred_1))
# Out:
# [[  112  1257]
#  [   36 12335]]
# 0.9501983592034818

# %%
from sklearn.naive_bayes import GaussianNB

gnb_clf = GaussianNB()

gnb_clf.fit(X_train,y_train)

pred = gnb_clf.predict(X_test)

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred))

pred = gnb_clf.predict(X_train)

print (confusion_matrix(y_train,pred))

print (f1_score(y_train,pred))
# Out:
# [[  16  296]
#  [  14 3110]]
# 0.9525267993874426
# [[   78  1291]
#  [   42 12329]]
# 0.9487130160440153

# %%
from sklearn.naive_bayes import MultinomialNB

mnb_clf = MultinomialNB()

mnb_clf.fit(X_train,y_train)

pred = mnb_clf.predict(X_test)

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred,average="macro"))

pred = mnb_clf.predict(X_train)

print (confusion_matrix(y_train,pred))

print (f1_score(y_train,pred,average="macro"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-0bcbea4002ee> in <module>
#       3 mnb_clf = MultinomialNB()
#       4
# ----> 5 mnb_clf.fit(X_train,y_train)
#       6
#       7 pred = mnb_clf.predict(X_test)
#
# ~/.local/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     602         self.feature_count_ = np.zeros((n_effective_classes, n_features),
#     603                                        dtype=np.float64)
# --> 604         self._count(X, Y)
#     605         alpha = self._check_alpha()
#     606         self._update_feature_log_prob(alpha)
#
# ~/.local/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     706         """Count and smooth feature occurrences."""
#     707         if np.any((X.data if issparse(X) else X) < 0):
# --> 708             raise ValueError("Input X must be non-negative")
#     709         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     710         self.class_count_ += Y.sum(axis=0)
#
# ValueError: Input X must be non-negative

# %%
Y

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()

qda.fit(X_train,y_train)

pred = qda.predict(X_test)

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred))

pred = qda.predict(X_train)

print (confusion_matrix(y_train,pred))

print (f1_score(y_train,pred))
# Out:
# [[  98  214]
#  [  97 3027]]
# 0.9511390416339357
# [[  512   857]
#  [  337 12034]]
# 0.9527353337027947

# %%
from sklearn.gaussian_process.kernels import RBF
from sklearn.gaussian_process import GaussianProcessClassifier

gpc = GaussianProcessClassifier(1.0 * RBF(1.0))

gpc.fit(X_train,y_train)

pred = gpc.predict(X_test)

print (confusion_matrix(y_test,pred))

print (f1_score(y_test,pred,average="macro"))

pred = gpc.predict(X_train)

print (confusion_matrix(y_train,pred))

print (f1_score(y_train,pred,average="macro"))
